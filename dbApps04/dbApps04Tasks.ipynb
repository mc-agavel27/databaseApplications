# %% [markdown]
# # Lesson 04 Task: SQL Basics (Track A)
#
# ## Database Applications Development
#
# ---
#
# ## Instructions
#
# Complete all exercises below. Write SQL queries to answer each question.
#
# **Resources:**
# - Keep `SQL_Reference_Guide.md` open
# - Review `dbApps04_Walkthrough.ipynb` for examples
# - Ask for help if stuck!
#
# **Submission:**
# - Complete all TODO sections
# - Test that all your queries run without errors
# - Push to GitHub: `databaseApplications/dbApps04_Task_TrackA.ipynb`
#
# Let's practice SQL! 🚀

# %% [markdown]
# ---
#
# ## Setup

# %%
import pandas as pd
import sqlite3

# Connect to database
conn = sqlite3.connect('titanic.db')
print("✅ Connected to database")
# Out:
# ✅ Connected to database

# %% [markdown]
# ---
#
# ## Part 1: SELECT Basics (5 queries)
#
# Practice selecting specific columns.

# %% [markdown]
# ### Query 1: Select All Columns
#
# **Task:** Write a query to select ALL columns from the passengers table. Limit to 5 rows.

# %%
# TODO: Write your query here
titanic = pd.read_csv("Titanic Dataset.csv")
conn = sqlite3.connect("titanic.db")

titanic.to_sql(
    name='passengers',           # The name of the SQL table we want to create in the database
    con=conn,                    # The active database connection (created with sqlite3.connect)
    if_exists='replace',         # If a table named 'passengers' already exists, delete it and write a new one
    index=False                  # Don't store the DataFrame's index as its own column in the database
)

                       
query_1 = "SELECT * FROM passengers LIMIT 5"


result_1 = pd.read_sql(query_1, conn)
display(result_1)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked  boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S     2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S    11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  None    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  None  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  None    NaN
#
#                          home.dest
# ...

# %% [markdown]
# ### Query 2: Select Name and Age
#
# **Task:** Select only the Name and Age columns. Show first 10 rows.

# %%
# TODO: Write your query
query_2 = "SELECT Name, Age FROM passengers LIMIT 10"

result_2 = pd.read_sql(query_2, conn)
display(result_2)
# Out:
#                                               name    age
# 0                    Allen, Miss. Elisabeth Walton  29.00
# 1                   Allison, Master. Hudson Trevor   0.92
# 2                     Allison, Miss. Helen Loraine   2.00
# 3             Allison, Mr. Hudson Joshua Creighton  30.00
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00
# 5                              Anderson, Mr. Harry  48.00
# 6                Andrews, Miss. Kornelia Theodosia  63.00
# 7                           Andrews, Mr. Thomas Jr  39.00
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.00
# 9                          Artagaveytia, Mr. Ramon  71.00

# %% [markdown]
# ### Query 3: Select Multiple Columns
#
# **Task:** Select Name, Age, Sex, and Survived columns. Show first 10 rows.

# %%
# TODO: Write your query
query_3 = "SELECT name, age, sex, survived FROM passengers LIMIT 10"

result_3 = pd.read_sql(query_3, conn)
display(result_3)
# Out:
#                                               name    age     sex  survived
# 0                    Allen, Miss. Elisabeth Walton  29.00  female         1
# 1                   Allison, Master. Hudson Trevor   0.92    male         1
# 2                     Allison, Miss. Helen Loraine   2.00  female         0
# 3             Allison, Mr. Hudson Joshua Creighton  30.00    male         0
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00  female         0
# 5                              Anderson, Mr. Harry  48.00    male         1
# 6                Andrews, Miss. Kornelia Theodosia  63.00  female         1
# 7                           Andrews, Mr. Thomas Jr  39.00    male         0
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.00  female         1
# 9                          Artagaveytia, Mr. Ramon  71.00    male         0

# %% [markdown]
# ### Query 4: Select Name, Pclass, and Fare
#
# **Task:** Select Name, Pclass, and Fare columns. Show first 10 rows.

# %%
# TODO: Write your query
query_4 = "SELECT name, pclass, fare FROM passengers LIMIT 10"

result_4 = pd.read_sql(query_4, conn)
display(result_4)
# Out:
#                                               name  pclass      fare
# 0                    Allen, Miss. Elisabeth Walton       1  211.3375
# 1                   Allison, Master. Hudson Trevor       1  151.5500
# 2                     Allison, Miss. Helen Loraine       1  151.5500
# 3             Allison, Mr. Hudson Joshua Creighton       1  151.5500
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  151.5500
# 5                              Anderson, Mr. Harry       1   26.5500
# 6                Andrews, Miss. Kornelia Theodosia       1   77.9583
# 7                           Andrews, Mr. Thomas Jr       1    0.0000
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)       1   51.4792
# 9                          Artagaveytia, Mr. Ramon       1   49.5042

# %% [markdown]
# ### Query 5: Your Choice!
#
# **Task:** Select ANY 3 columns you want. Show 10 rows. Explain your choice below.

# %%
# TODO: Write your query
query_5 = "SELECT name, age, pclass FROM passengers LIMIT 10"

result_5 = pd.read_sql(query_5, conn)
display(result_5)
# Out:
#                                               name    age  pclass
# 0                    Allen, Miss. Elisabeth Walton  29.00       1
# 1                   Allison, Master. Hudson Trevor   0.92       1
# 2                     Allison, Miss. Helen Loraine   2.00       1
# 3             Allison, Mr. Hudson Joshua Creighton  30.00       1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.00       1
# 5                              Anderson, Mr. Harry  48.00       1
# 6                Andrews, Miss. Kornelia Theodosia  63.00       1
# 7                           Andrews, Mr. Thomas Jr  39.00       1
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.00       1
# 9                          Artagaveytia, Mr. Ramon  71.00       1

# %% [markdown]
# **Why I chose these columns:** I thought that name, age and class were the most important columns about the people (surviving was also important, but it was exchangeable with pclass)

# %% [markdown]
# ---
#
# ## Part 2: WHERE Clause - Filtering (6 queries)
#
# Practice filtering rows with conditions.

# %% [markdown]
# ### Query 6: Passengers Over Age 30
#
# **Task:** Find all passengers older than 30. Show Name and Age.

# %%
# TODO: Write your query
query_6 = "SELECT name, age FROM passengers WHERE age > 30"

result_6 = pd.read_sql(query_6, conn)
print(f"Found {len(result_6)} passengers over 30")
display(result_6.head(10))
# Out:
# Found 437 passengers over 30
#                                               name   age
# 0                              Anderson, Mr. Harry  48.0
# 1                Andrews, Miss. Kornelia Theodosia  63.0
# 2                           Andrews, Mr. Thomas Jr  39.0
# 3    Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0
# 4                          Artagaveytia, Mr. Ramon  71.0
# 5                           Astor, Col. John Jacob  47.0
# 6             Barkworth, Mr. Algernon Henry Wilson  80.0
# 7  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50.0
# 8                            Bazzani, Miss. Albina  32.0
# 9                             Beattie, Mr. Thomson  36.0

# %% [markdown]
# ### Query 7: Female Passengers
#
# **Task:** Find all female passengers. Show Name, Age, and Sex. Limit to 10 rows.

# %%
# TODO: Write your query (remember: text needs single quotes!)
query_7 = "SELECT name, age, sex FROM passengers WHERE sex == 'female' LIMIT 10"

result_7 = pd.read_sql(query_7, conn)
display(result_7)
# Out:
#                                                 name   age     sex
# 0                      Allen, Miss. Elisabeth Walton  29.0  female
# 1                       Allison, Miss. Helen Loraine   2.0  female
# 2    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0  female
# 3                  Andrews, Miss. Kornelia Theodosia  63.0  female
# 4      Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0  female
# 5  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.0  female
# 6                      Aubart, Mme. Leontine Pauline  24.0  female
# 7                       Barber, Miss. Ellen "Nellie"  26.0  female
# 8    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50.0  female
# 9                              Bazzani, Miss. Albina  32.0  female

# %% [markdown]
# ### Query 8: First Class Passengers
#
# **Task:** Find all first class passengers (Pclass = 1). Show Name, Pclass, and Fare. Limit to 10.

# %%
# TODO: Write your query
query_8 = "SELECT name, pclass, fare FROM passengers WHERE pclass == 1 LIMIT 10"

result_8 = pd.read_sql(query_8, conn)
display(result_8)
# Out:
#                                               name  pclass      fare
# 0                    Allen, Miss. Elisabeth Walton       1  211.3375
# 1                   Allison, Master. Hudson Trevor       1  151.5500
# 2                     Allison, Miss. Helen Loraine       1  151.5500
# 3             Allison, Mr. Hudson Joshua Creighton       1  151.5500
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1  151.5500
# 5                              Anderson, Mr. Harry       1   26.5500
# 6                Andrews, Miss. Kornelia Theodosia       1   77.9583
# 7                           Andrews, Mr. Thomas Jr       1    0.0000
# 8    Appleton, Mrs. Edward Dale (Charlotte Lamson)       1   51.4792
# 9                          Artagaveytia, Mr. Ramon       1   49.5042

# %% [markdown]
# ### Query 9: Survivors
#
# **Task:** Find all passengers who survived (Survived = 1). Show Name, Age, Sex, and Survived. Limit to 15.

# %%
# TODO: Write your query
query_9 = "SELECT name, age, sex, survived FROM passengers WHERE survived == 1 LIMIT 15"

result_9 = pd.read_sql(query_9, conn)
display(result_9)
# Out:
#                                                  name    age     sex  survived
# 0                       Allen, Miss. Elisabeth Walton  29.00  female         1
# 1                      Allison, Master. Hudson Trevor   0.92    male         1
# 2                                 Anderson, Mr. Harry  48.00    male         1
# 3                   Andrews, Miss. Kornelia Theodosia  63.00  female         1
# 4       Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.00  female         1
# 5   Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.00  female         1
# 6                       Aubart, Mme. Leontine Pauline  24.00  female         1
# 7                        Barber, Miss. Ellen "Nellie"  26.00  female         1
# 8                Barkworth, Mr. Algernon Henry Wilson  80.00    male         1
# 9     Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50.00  female         1
# 10                              Bazzani, Miss. Albina  32.00  female         1
# ...

# %% [markdown]
# ### Query 10: Passengers Who Paid High Fares
#
# **Task:** Find passengers who paid more than $50. Show Name, Fare, and Pclass. Limit to 10.

# %%
# TODO: Write your query
query_10 = "SELECT name, fare, pclass FROM passengers WHERE fare > 50 LIMIT 10"

result_10 = pd.read_sql(query_10, conn)
display(result_10)
# Out:
#                                                 name      fare  pclass
# 0                      Allen, Miss. Elisabeth Walton  211.3375       1
# 1                     Allison, Master. Hudson Trevor  151.5500       1
# 2                       Allison, Miss. Helen Loraine  151.5500       1
# 3               Allison, Mr. Hudson Joshua Creighton  151.5500       1
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500       1
# 5                  Andrews, Miss. Kornelia Theodosia   77.9583       1
# 6      Appleton, Mrs. Edward Dale (Charlotte Lamson)   51.4792       1
# 7                             Astor, Col. John Jacob  227.5250       1
# 8  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  227.5250       1
# 9                      Aubart, Mme. Leontine Pauline   69.3000       1

# %% [markdown]
# ### Query 11: Children (Age 12 or Under)
#
# **Task:** Find children age 12 or under. Show Name and Age. Limit to 10.

# %%
# TODO: Write your query
query_11 = "SELECT name, age FROM passengers WHERE age <= 10"

result_11 = pd.read_sql(query_11, conn)
display(result_11)
# Out:
#                                name    age
# 0    Allison, Master. Hudson Trevor   0.92
# 1      Allison, Miss. Helen Loraine   2.00
# 2         Dodge, Master. Washington   4.00
# 3   Spedden, Master. Robert Douglas   6.00
# 4         Becker, Master. Richard F   1.00
# ..                              ...    ...
# 81       Strom, Miss. Telma Matilda   2.00
# 82  Thomas, Master. Assad Alexander   0.42
# 83   Touma, Master. Georges Youssef   7.00
# 84       Touma, Miss. Maria Youssef   9.00
# 85        Van Impe, Miss. Catharina  10.00
#
# [86 rows x 2 columns]

# %% [markdown]
# ---
#
# ## Part 3: Multiple Conditions with AND (3 queries)

# %% [markdown]
# ### Query 12: Female Survivors
#
# **Task:** Find female passengers who survived. Show Name, Age, Sex, and Survived. Limit to 10.

# %%
# TODO: Write your query (use AND)
query_12 = "SELECT name, age, sex, survived FROM passengers WHERE sex == 'female' AND survived == 1 LIMIT 10"

result_12 = pd.read_sql(query_12, conn)
display(result_12)
# Out:
#                                                 name   age     sex  survived
# 0                      Allen, Miss. Elisabeth Walton  29.0  female         1
# 1                  Andrews, Miss. Kornelia Theodosia  63.0  female         1
# 2      Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0  female         1
# 3  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.0  female         1
# 4                      Aubart, Mme. Leontine Pauline  24.0  female         1
# 5                       Barber, Miss. Ellen "Nellie"  26.0  female         1
# 6    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50.0  female         1
# 7                              Bazzani, Miss. Albina  32.0  female         1
# 8   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0  female         1
# 9                              Bidois, Miss. Rosalie  42.0  female         1

# %% [markdown]
# ### Query 13: Young Adults (Ages 18-30)
#
# **Task:** Find passengers between age 18 and 30 (inclusive). Show Name and Age. Limit to 15.
#
# **Hint:** You need TWO conditions with AND: `Age >= 18 AND Age <= 30`

# %%
# TODO: Write your query
query_13 = "SELECT name, age FROM passengers WHERE age >= 18 AND age <= 30 LIMIT 15"

result_13 = pd.read_sql(query_13, conn)
display(result_13)
# Out:
#                                                  name   age
# 0                       Allen, Miss. Elisabeth Walton  29.0
# 1                Allison, Mr. Hudson Joshua Creighton  30.0
# 2     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0
# 3   Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.0
# 4                       Aubart, Mme. Leontine Pauline  24.0
# 5                        Barber, Miss. Ellen "Nellie"  26.0
# 6                            Baxter, Mr. Quigg Edmond  24.0
# 7                               Behr, Mr. Karl Howell  26.0
# 8                                   Bird, Miss. Ellen  29.0
# 9                                 Birnbaum, Mr. Jakob  25.0
# 10                            Bishop, Mr. Dickinson H  25.0
# 11            Bishop, Mrs. Dickinson H (Helen Walton)  19.0
# 12          Bjornstrom-Steffansson, Mr. Mauritz Hakan  28.0
# 13                            Bonnell, Miss. Caroline  30.0
# 14                        Bowerman, Miss. Elsie Edith  22.0

# %% [markdown]
# ### Query 14: Male First Class Survivors
#
# **Task:** Find male passengers in first class who survived. Show Name, Age, Sex, Pclass, Survived. Limit to 10.
#
# **Hint:** THREE conditions with AND!

# %%
# TODO: Write your query
query_14 = "SELECT name, age, sex, pclass, survived FROM passengers WHERE sex == 'male' AND pclass == 1 AND survived == 1"

result_14 = pd.read_sql(query_14, conn)
display(result_14)
# Out:
#                                     name    age   sex  pclass  survived
# 0         Allison, Master. Hudson Trevor   0.92  male       1         1
# 1                    Anderson, Mr. Harry  48.00  male       1         1
# 2   Barkworth, Mr. Algernon Henry Wilson  80.00  male       1         1
# 3          Beckwith, Mr. Richard Leonard  37.00  male       1         1
# 4                  Behr, Mr. Karl Howell  26.00  male       1         1
# ..                                   ...    ...   ...     ...       ...
# 56              Taylor, Mr. Elmer Zebley  48.00  male       1         1
# 57           Thayer, Mr. John Borland Jr  17.00  male       1         1
# 58       Tucker, Mr. Gilbert Milligan Jr  31.00  male       1         1
# 59       Williams, Mr. Richard Norris II  21.00  male       1         1
# 60                     Woolner, Mr. Hugh    NaN  male       1         1
#
# [61 rows x 5 columns]

# %% [markdown]
# ---
#
# ## Part 4: ORDER BY - Sorting (4 queries)

# %% [markdown]
# ### Query 15: Sort by Age (Youngest First)
#
# **Task:** Show Name and Age, sorted by age from youngest to oldest. Limit to 10.

# %%
# TODO: Write your query
query_15 = "SELECT name, age FROM passengers ORDER BY age LIMIT 10"

result_15 = pd.read_sql(query_15, conn)
display(result_15)
# Out:
#                                                 name   age
# 0                                Baumann, Mr. John D  None
# 1      Bradley, Mr. George ("George Arthur Brayton")  None
# 2                          Brewe, Dr. Arthur Jackson  None
# 3                              Cairns, Mr. Alexander  None
# 4  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...  None
# 5             Chibnall, Mrs. (Edith Martha Bowerman)  None
# 6              Chisholm, Mr. Roderick Robert Crispin  None
# 7                        Clifford, Mr. George Quincy  None
# 8                          Crafton, Mr. John Bertram  None
# 9                                 Farthing, Mr. John  None

# %% [markdown]
# ### Query 16: Sort by Age (Oldest First)
#
# **Task:** Show Name and Age, sorted by age from oldest to youngest. Limit to 10.
#
# **Hint:** Use DESC!

# %%
# TODO: Write your query
query_16 = "SELECT name, age FROM passengers ORDER BY age DESC LIMIT 10"

result_16 = pd.read_sql(query_16, conn)
display(result_16)
# Out:
#                                                 name   age
# 0               Barkworth, Mr. Algernon Henry Wilson  80.0
# 1  Cavendish, Mrs. Tyrell William (Julia Florence...  76.0
# 2                                Svensson, Mr. Johan  74.0
# 3                            Artagaveytia, Mr. Ramon  71.0
# 4                          Goldschmidt, Mr. George B  71.0
# 5                               Connors, Mr. Patrick  70.5
# 6                       Crosby, Capt. Edward Gifford  70.0
# 7                        Mitchell, Mr. Henry Michael  70.0
# 8                                 Straus, Mr. Isidor  67.0
# 9                              Wheadon, Mr. Edward H  66.0

# %% [markdown]
# ### Query 17: Sort by Fare (Highest First)
#
# **Task:** Show Name, Fare, and Pclass, sorted by fare from highest to lowest. Limit to 10.

# %%
# TODO: Write your query
query_17 = "SELECT name, fare, pclass FROM passengers ORDER BY fare DESC LIMIT 10"

result_17 = pd.read_sql(query_17, conn)
display(result_17)
# Out:
#                                                 name      fare  pclass
# 0                 Cardeza, Mr. Thomas Drake Martinez  512.3292       1
# 1  Cardeza, Mrs. James Warburton Martinez (Charlo...  512.3292       1
# 2                             Lesurer, Mr. Gustave J  512.3292       1
# 3                                   Ward, Miss. Anna  512.3292       1
# 4                     Fortune, Miss. Alice Elizabeth  263.0000       1
# 5                         Fortune, Miss. Ethel Flora  263.0000       1
# 6                         Fortune, Miss. Mabel Helen  263.0000       1
# 7                     Fortune, Mr. Charles Alexander  263.0000       1
# 8                                  Fortune, Mr. Mark  263.0000       1
# 9                Fortune, Mrs. Mark (Mary McDougald)  263.0000       1

# %% [markdown]
# ### Query 18: Sort by Name (Alphabetical)
#
# **Task:** Show Name, Age, and Sex, sorted alphabetically by name. Limit to 15.

# %%
# TODO: Write your query
query_18 = "SELECT name, age, sex FROM passengers ORDER BY name LIMIT 15"

result_18 = pd.read_sql(query_18, conn)
display(result_18)
# Out:
#                                               name    age     sex
# 0                              Abbing, Mr. Anthony  42.00    male
# 1                    Abbott, Master. Eugene Joseph  13.00    male
# 2                      Abbott, Mr. Rossmore Edward  16.00    male
# 3                 Abbott, Mrs. Stanton (Rosa Hunt)  35.00  female
# 4                      Abelseth, Miss. Karen Marie  16.00  female
# 5                    Abelseth, Mr. Olaus Jorgensen  25.00    male
# 6                              Abelson, Mr. Samuel  30.00    male
# 7            Abelson, Mrs. Samuel (Hannah Wizosky)  28.00  female
# 8         Abrahamsson, Mr. Abraham August Johannes  20.00    male
# 9        Abrahim, Mrs. Joseph (Sophie Halaut Easu)  18.00  female
# 10                  Adahl, Mr. Mauritz Nils Martin  30.00    male
# 11                                 Adams, Mr. John  26.00    male
# 12  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  40.00  female
# ...

# %% [markdown]
# ---
#
# ## Part 5: Combined Queries (3 challenges)
#
# Put it all together: SELECT, WHERE, ORDER BY, LIMIT

# %% [markdown]
# ### Query 19: Young Female Survivors
#
# **Task:** Find female passengers under age 20 who survived. Show Name, Age, Sex, Survived. Sort by age (youngest first). Limit to 10.

# %%
# TODO: Write your query
query_19 = "SELECT name, age, sex survived FROM passengers WHERE sex == 'female' AND age < 20 ORDER BY age LIMIT 10"

result_19 = pd.read_sql(query_19, conn)
display(result_19)
# Out:
#                                       name   age survived
# 0  Dean, Miss. Elizabeth Gladys "Millvina"  0.17   female
# 1                   Baclini, Miss. Eugenie  0.75   female
# 2            Baclini, Miss. Helene Barbara  0.75   female
# 3                    West, Miss. Barbara J  0.92   female
# 4                    Laroche, Miss. Louise  1.00   female
# 5             Johnson, Miss. Eleanor Ileen  1.00   female
# 6             Klasen, Miss. Gertrud Emilia  1.00   female
# 7              Nakid, Miss. Maria ("Mary")  1.00   female
# 8          Sandstrom, Miss. Beatrice Irene  1.00   female
# 9             Allison, Miss. Helen Loraine  2.00   female

# %% [markdown]
# ### Query 20: Wealthy First Class Passengers
#
# **Task:** Find first class passengers who paid more than $100. Show Name, Pclass, Fare. Sort by fare (highest first). Limit to 10.

# %%
# TODO: Write your query
query_20 = "SELECT name, pclass, fare FROM passengers WHERE pclass == 1 AND fare > 100 ORDER BY fare DESC LIMIT 10"

result_20 = pd.read_sql(query_20, conn)
display(result_20)
# Out:
#                                                 name  pclass      fare
# 0                 Cardeza, Mr. Thomas Drake Martinez       1  512.3292
# 1  Cardeza, Mrs. James Warburton Martinez (Charlo...       1  512.3292
# 2                             Lesurer, Mr. Gustave J       1  512.3292
# 3                                   Ward, Miss. Anna       1  512.3292
# 4                     Fortune, Miss. Alice Elizabeth       1  263.0000
# 5                         Fortune, Miss. Ethel Flora       1  263.0000
# 6                         Fortune, Miss. Mabel Helen       1  263.0000
# 7                     Fortune, Mr. Charles Alexander       1  263.0000
# 8                                  Fortune, Mr. Mark       1  263.0000
# 9                Fortune, Mrs. Mark (Mary McDougald)       1  263.0000

# %% [markdown]
# ### Query 21: Create Your Own Challenge!
#
# **Task:** Write your own query using:
# - SELECT (specific columns)
# - WHERE (at least 2 conditions with AND)
# - ORDER BY
# - LIMIT
#
# Describe what you're looking for: male, first class survivors in the name, age, pclass and survivors, ordered by survived and limited by 15

# %% [markdown]
# **My query finds:** (describe here)

# %%
# TODO: Write your creative query!
query_21 = "SELECT name, age, pclass, survived FROM passengers WHERE sex == 'male' AND pclass == 1 ORDER BY survived LIMIT 15"

result_21 = pd.read_sql(query_21, conn)
display(result_21)
# Out:
#                                     name   age  pclass  survived
# 0   Allison, Mr. Hudson Joshua Creighton  30.0       1         0
# 1                 Andrews, Mr. Thomas Jr  39.0       1         0
# 2                Artagaveytia, Mr. Ramon  71.0       1         0
# 3                 Astor, Col. John Jacob  47.0       1         0
# 4                    Baumann, Mr. John D   NaN       1         0
# 5               Baxter, Mr. Quigg Edmond  24.0       1         0
# 6                   Beattie, Mr. Thomson  36.0       1         0
# 7                    Birnbaum, Mr. Jakob  25.0       1         0
# 8           Blackwell, Mr. Stephen Weart  45.0       1         0
# 9               Borebank, Mr. John James  42.0       1         0
# 10               Brady, Mr. John Bertram  41.0       1         0
# 11                    Brandeis, Mr. Emil  48.0       1         0
# 12             Brewe, Dr. Arthur Jackson   NaN       1         0
# ...

# %% [markdown]
# ---
#
# ## Reflection Questions
#
# Answer these questions in the markdown cells below:

# %% [markdown]
# ### Question 1: SQL vs. pandas
#
# **How is writing WHERE in SQL similar to filtering in pandas? How is it different?**
#
# *Your answer here:* It's different with similar concepts, but differs with how it's done (syntax)

# %% [markdown]
# ### Question 2: ORDER BY
#
# **When would you use ORDER BY ASC vs. ORDER BY DESC? Give a real-world example for each.**
#
# *Your answer here:* Order by asc is good for when you want to see the fastest result in a datasheet, and order by desc is good when you want to find the slowest process in a datasheet.

# %% [markdown]
# ### Question 3: Most Challenging
#
# **Which query was hardest for you? Why? How did you figure it out?**
#
# *Your answer here:* Query 20, because I mostly just messed up on syntax and kind of forgot how it worked halfway through, but I figured it out by slowly fixing the parts I messed up

# %% [markdown]
# ---
#
# ## Clean Up

# %%
# Close database connection
conn.close()
print("✅ Connection closed. Great work!")

# %% [markdown]
# ---
#
# ## ✅ Before You Submit
#
# Make sure you:
# - [ ] Completed all 21 queries
# - [ ] Answered all reflection questions
# - [ ] Tested that all cells run without errors
# - [ ] Used proper SQL syntax (SELECT → FROM → WHERE → ORDER BY → LIMIT)
# - [ ] Put single quotes around text values
# - [ ] Saved your file
#
# **Submit via GitHub:** `databaseApplications/dbApps04_Task_TrackA.ipynb`
#
# **Great work!** You've learned SQL basics! 🎉
